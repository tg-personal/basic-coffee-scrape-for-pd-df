# %%
# Webscrape Verve website, the datasource, for all Verve products currently listed into a pandas dataframe.
# Using this url: https://www.vervecoffee.com/collections/all-coffee?view=products

# %%
# Import necessary python packages
import pandas as pd
import requests
import json
import re

# %%
# Send HTTP GET request to the Verve url
source_url = 'https://www.vervecoffee.com/collections/all-coffee?view=products'
source = requests.get(source_url)

# %%
# Convert extract into a string
source_text = source.content.decode('utf-8')

# %%
# Define starting and ending indices of desired substring
start_index = source_text.find('"title":"All Coffee","productVariants":[')
end_index = source_text.find(']', start_index)

# %%
# Extract substring between the start and end indices
substring = source_text[start_index + len('"title":"All Coffee","productVariants":['):end_index + 1]

# %%
# View substring output for validation
substring
# Out:
# '{"id":"40006386810963","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/Bronson_1.png?v=1658421910"},"price":{"amount":16.0,"currencyCode":"USD"},"product":{"id":"6777135988819","title":"Bronson French Roast Craft Instant Coffee","untranslatedTitle":"Bronson French Roast Craft Instant Coffee","vendor":"Verve Coffee","type":"Coffee"},"sku":"4210621-0902100","title":"Default Title","untranslatedTitle":"Default Title"},{"id":"40006386876499","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/BuenaVista_1.png?v=1658421973"},"price":{"amount":16.0,"currencyCode":"USD"},"product":{"id":"6777136054355","title":"Buena Vista Dark Roast Craft Instant Coffee","untranslatedTitle":"Buena Vista Dark Roast Craft Instant Coffee","vendor":"Verve Coffee","type":"Coffee"},"sku":"SM-0099","title":"Default Title","untranslatedTitle":"Default Title"},{"id":"40006387138643","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/Variety_1.png?v=1658421791"},"price":{"amount":18.0,"currencyCode":"USD"},"product":{"id":"6777136316499","title":"Craft Instant Coffee Variety Pack","untranslatedTitle":"Craft Instant Coffee Variety Pack","vendor":"Verve Coffee","type":"Coffee"},"sku":"4210821-0902100","title":"Default Title","untranslatedTitle":"Default Title"},{"id":"40006409322579","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/Seabright_1.png?v=1658422099"},"price":{"amount":16.0,"currencyCode":"USD"},"product":{"id":"6777140183123","title":"Seabright House Blend Craft Instant Coffee","untranslatedTitle":"Seabright House Blend Craft Instant Coffee","vendor":"Verve Coffee","type":"Coffee"},"sku":"SM-0336","title":"Default Title","untranslatedTitle":"Default Title"},{"id":"40006409355347","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/Sermon_1.png?v=1658422154"},"price":{"amount":16.0,"currencyCode":"USD"},"product":{"id":"6777140215891","title":"Sermon Craft Instant Coffee","untranslatedTitle":"Sermon Craft Instant Coffee","vendor":"Verve Coffee","type":"Coffee"},"sku":"4210421-0902100","title":"Default Title","untranslatedTitle":"Default Title"},{"id":"40006410338387","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/Streetlevel_1.png?v=1658422227"},"price":{"amount":16.0,"currencyCode":"USD"},"product":{"id":"6777140346963","title":"Streetlevel Craft Instant Coffee","untranslatedTitle":"Streetlevel Craft Instant Coffee","vendor":"Verve Coffee","type":"Coffee"},"sku":"SM-0097","title":"Default Title","untranslatedTitle":"Default Title"},{"id":"40006410403923","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/1950_1.png?v=1658421845"},"price":{"amount":16.0,"currencyCode":"USD"},"product":{"id":"6777140412499","title":"The 1950 Craft Instant Coffee","untranslatedTitle":"The 1950 Craft Instant Coffee","vendor":"Verve Coffee","type":"Coffee"},"sku":"4210521-0902100","title":"Default Title","untranslatedTitle":"Default Title"},{"id":"40006410698835","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/Vancouver_1.png?v=1658422278"},"price":{"amount":16.0,"currencyCode":"USD"},"product":{"id":"6777140707411","title":"Vancouver Decaf Craft Instant Coffee","untranslatedTitle":"Vancouver Decaf Craft Instant Coffee","vendor":"Verve Coffee","type":"Coffee"},"sku":"SM-0100","title":"Default Title","untranslatedTitle":"Default Title"},{"id":"39923041108051","image":{"src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0035\\/9372\\/products\\/Streetlevel_10edf3d5-1dce-42cf-88a3-8d9ee4e0d976.png?v=1670627826"},"price":{"amount":18.75,"currencyCode":"USD"},"product":{"id":"6762954096723","title":"Streetlevel","untranslatedTitle":"Streetlevel","vendor":"Verve Coffee","type":"Coffee"},"sku":"CO-0182","title":"Whole Bean \\/ 12 OZ","untranslatedTitle":"Whole Bean \\/ 12 OZ"},{"id": ...

# %%
# Define starting and ending indices of the JSON data within substring
start_index = substring.index('{')
end_index = substring.rindex('}') + 1

# Extract JSON data from substring
json_data = substring[start_index:end_index]

# %%
# Parse JSON data
product_data = json.loads("[" + json_data + "]")

# %%
# Create empty list to store the Verve cofffe product information
products_list = []

# %%
# Iterate over each Verve cofffe product in product_data
for product in product_data:
    product_id = product['id']
    image_src = product['image']['src']
    price_amount = product['price']['amount']
    price_currency = product['price']['currencyCode']
    product_title = product['product']['title']
    vendor = product['product']['vendor']
    product_type = product['product']['type']
    sku = product['sku']

    # Define a dictionary with the product information for each listed Verve cofffe product
    product_info = {
        'Product_ID': product_id,
        'Image_Source': image_src,
        'Price_Amount': price_amount,
        'Price_Currency': price_currency,
        'Product_Title': product_title,
        'Vendor': vendor,
        'Product_Type': product_type,
        'SKU': sku
    }

    # Append the dictionary to products_list
    products_list.append(product_info)

# %%
# Create pandas dataFrame from products_list
df_products = pd.DataFrame(products_list)

# %%
# View df_products output
df_products
# Out:
#         Product_ID                                       Image_Source  \
# 0   40006386810963  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 1   40006386876499  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 2   40006387138643  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 3   40006409322579  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 4   40006409355347  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 5   40006410338387  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 6   40006410403923  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 7   40006410698835  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 8   39923041108051  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 9   39923040944211  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 10  39923041927251  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 11  39923041861715  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 12  39923044483155  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 13  39923044909139  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 14  39923046252627  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 15  40006401425491  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 16  40006400868435  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 17  40006408339539  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 18  40006396674131  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 19  40006402703443  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 20  40074088480851  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 21  29408729989203  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 22  40098135605331  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 23  40098125938771  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 24  40037188599891  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 25  40037188403283  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 26  40037189156947  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 27  40037188730963  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 28  39640256184403  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 29  39640261001299  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 30  39640251138131  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 31  40494808137811  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 32  40006411911251  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 33  32375536877651  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 34  40006412959827  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 35  40098136981587  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 36  40572179218515  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 37  40572178726995  https://cdn.shopify.com/s/files/1/0035/9372/pr...
# 38  40773336301651  https://cdn.shopify.com/s/files/1/0035/9372/fi...
# 39  40773343543379  https://cdn.shopify.com/s/files/1/0035/9372/fi...
# 40  40773342658643  https://cdn.shopify.com/s/files/1/0035/9372/fi...
# 41  40773336957011  https://cdn.shopify.com/s/files/1/0035/9372/fi...
# 42  40773340987475  https://cdn.shopify.com/s/files/1/0035/9372/fi...
# 43  40791534927955  https://cdn.shopify.com/s/files/1/0035/9372/fi...
#
#     Price_Amount Price_Currency                                 Product_Title  \
# 0          16.00            USD     Bronson French Roast Craft Instant Coffee
# 1          16.00            USD   Buena Vista Dark Roast Craft Instant Coffee
# 2          18.00            USD             Craft Instant Coffee Variety Pack
# 3          16.00            USD    Seabright House Blend Craft Instant Coffee
# 4          16.00            USD                   Sermon Craft Instant Coffee
# 5          16.00            USD              Streetlevel Craft Instant Coffee
# 6          16.00            USD                 The 1950 Craft Instant Coffee
# 7          16.00            USD          Vancouver Decaf Craft Instant Coffee
# 8          18.75            USD                                   Streetlevel
# 9          17.75            USD                          Bronson French Roast
# 10         18.25            USD                         Seabright House Blend
# 11         17.75            USD                        Buena Vista Dark Roast
# 12         19.50            USD                   Vancouver Swiss Water Decaf
# 13         18.75            USD                                        Sermon
# 14         19.50            USD                                      The 1950
# 15         20.00            USD        Roaster's Choice Espresso Subscription
# 16         18.75            USD           Roaster's Choice Blend Subscription
# 17         22.00            USD   Roaster's Choice Single Origin Subscription
# 18         22.00            USD          Roaster's Choice Africa Subscription
# 19         22.00            USD   Roaster's Choice Latin America Subscription
# 20         18.75            USD                         Jose Alvarado Dripkit
# 21         17.50            USD                       Seabright House Dripkit
# 22         15.95            USD          Flash Brew Oatmilk Latte - Chocolate
# 23         15.95            USD     Flash Brew Oatmilk Latte - Honey Lavender
# 24         15.00            USD       Flash Brew Nitro Coffee - Single Origin
# 25         15.00            USD        Flash Brew Nitro Coffee - The Original
# 26         22.50            USD      Flash Brew Nitro Coffee - Variety 6-Pack
# 27         15.00            USD     Flash Brew Nitro Coffee - Vancouver Decaf
# 28         48.00            USD     The 1950 Dose & Brew Craft Instant Coffee
# 29         48.00            USD  Buena Vista Dose & Brew Craft Instant Coffee
# 30         48.00            USD  Streetlevel Dose & Brew Craft Instant Coffee
# 31         21.00            USD                        Guji Highlands Natural
# 32         22.00            USD                                  Wilder Blend
# 33         18.00            USD             Wilder Blend Craft Instant Coffee
# 34         36.00            USD              Wilder Seasonal Blend Coffee Set
# 35         15.95            USD       Flash Brew Oatmilk Latte - The Original
# 36         22.75            USD                             Chachagüí Natural
# 37         35.00            USD                Sumava Gesha Farmlevel Reserve
# 38         24.25            USD                                     Chelbessa
# 39         22.75            USD                                        Hunapu
# 40         20.50            USD                                 Jose Alvarado
# 41         22.00            USD                                         Yasal
# 42         28.00            USD              El Tesoro Tabi Farmlevel Reserve
# 43         20.00            USD                               Same Folk Blend
#
#           Vendor Product_Type                SKU
# 0   Verve Coffee       Coffee    4210621-0902100
# 1   Verve Coffee       Coffee            SM-0099
# 2   Verve Coffee       Coffee    4210821-0902100
# 3   Verve Coffee       Coffee            SM-0336
# 4   Verve Coffee       Coffee    4210421-0902100
# 5   Verve Coffee       Coffee            SM-0097
# 6   Verve Coffee       Coffee    4210521-0902100
# 7   Verve Coffee       Coffee            SM-0100
# 8   Verve Coffee       Coffee            CO-0182
# 9   Verve Coffee       Coffee            CO-0020
# 10  Verve Coffee       Coffee            CO-0172
# 11  Verve Coffee       Coffee            CO-0160
# 12  Verve Coffee       Coffee            CO-0193
# 13  Verve Coffee       Coffee            CO-0176
# 14  Verve Coffee       Coffee            CO-0154
# 15  Verve Coffee       Coffee    1212720-0302100
# 16  Verve Coffee       Coffee    1212520-0302100
# 17  Verve Coffee       Coffee    1302920-0302100
# 18  Verve Coffee       Coffee    1332320-0302100
# 19  Verve Coffee       Coffee    1322820-0302100
# 20  Verve Coffee       Coffee            SM-0508
# 21  Verve Coffee       Coffee  4210220-004000000
# 22  Verve Coffee       Coffee            OM-0049
# 23  Verve Coffee       Coffee            OM-0050
# 24  Verve Coffee       Coffee            FB-0061
# 25  Verve Coffee       Coffee            FB-0059
# 26  Verve Coffee       Coffee            FB-0062
# 27  Verve Coffee       Coffee            FB-0060
# 28  Verve Coffee       Coffee    4211621-0902100
# 29  Verve Coffee       Coffee    4211221-0902100
# 30  Verve Coffee       Coffee    4211121-0902100
# 31  Verve Coffee       Coffee    1330423-0302100
# 32  Verve Coffee       Coffee    1210121-0302100
# 33  Verve Coffee       Coffee    4210121-0902100
# 34  Verve Coffee       Coffee            SM-0477
# 35  Verve Coffee       Coffee            OM-0048
# 36  Verve Coffee       Coffee    1320723-0302100
# 37  Verve Coffee       Coffee    1320923-0202100
# 38  Verve Coffee       Coffee    1331423-0302100
# 39  Verve Coffee       Coffee    1329120-0302100
# 40  Verve Coffee       Coffee    1328120-0302100
# 41  Verve Coffee       Coffee    1321822-0302100
# 42  Verve Coffee       Coffee    1321523-0202100
# 43  Verve Coffee       Coffee            CO-0639

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product_ID      44 non-null     object
#  1   Image_Source    44 non-null     object
#  2   Price_Amount    44 non-null     float64
#  3   Price_Currency  44 non-null     object
#  4   Product_Title   44 non-null     object
#  5   Vendor          44 non-null     object
#  6   Product_Type    44 non-null     object
#  7   SKU             44 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 2.9+ KB

# %% [markdown]
# # RAW HTML output reference:

# %%
# 'https://www.vervecoffee.com/collections/all-coffee?view=products'
source_text
# Out:
# '\n\n\n\n<!doctype html>\n<html class="no-js" lang="en">\n  <head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <meta name="theme-color" content="">\n    <link rel="canonical" href="https://www.vervecoffee.com/collections/all-coffee">\n    <link rel="preconnect" href="https://cdn.shopify.com" crossorigin>\n    <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script><link rel="icon" type="image/png" href="//cdn.shopify.com/s/files/1/0035/9372/files/favicon_33d2d288-2905-49cf-86a5-8525204526bc_32x32.png?v=1650427325"><link rel="preconnect" href="https://fonts.shopifycdn.com" crossorigin><title>All Coffee</title><script>window.dataLayer = window.dataLayer || [];</script>\n      <!-- Google Tag Manager -->\n<script>\n  window.dataLayer = window.dataLayer || []; \n  dataLayer.push({\n      \'event\': \'bva_gtm_init\',\n      \'template\': {\n        \'active\': "collection",\n        \'name\': "collection",\n        \'directory\': null,\n      },\n      \n      \'localization\': {\n          \'country\': "US",\n          \'currency\': "USD",\n          \'language\': "en"\n        },\n      \n      \n      \n      \n      \n  });\n  </script>\n  <!-- GTM ID added via Theme Settings -->\n  <script>\n  (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n  new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n  \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n  })(window,document,\'script\',\'dataLayer\',\'GTM-T59C5BT\');\n  </script>\n  <!-- End Google Tag Manager -->\n\n\n    \n\n    \n\n    \n\n<meta property="og:site_name" content="Verve Coffee Roasters">\n<meta property="og:url" content="https://www.vervecoffee.com/collections/all-coffee">\n<meta property="og:title" content="All Coffee">\n<meta property="og:type" content="product.group">\n<meta property="og:description" content="Order Coffee Online from Verve Coffee Roasters. Hand-roasted daily, enjoy craft coffees with unique tasting &amp; roasting profiles. Free Shipping on orders $35+."><meta property="og:image" content="http://cdn.shopify.com/s/files/1/0035/9372/files/logo_0a340eea-4588-4b36-9346-b6a7e2aed95b.png?v=1650427327">\n  <meta property="og:image:secure_url" content="https://cdn.shopify.com/s/files/1/0035/9372/files/logo_0a340eea-4588-4b36-9346-b6a7e2aed95b.png?v=1650427327">\n  <meta property="og:image:width" content="1200">\n  <meta property="og:image:height" content="628"><meta name="twitter:site" content="@vervecoffee"><meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:title" content="All Coffee">\n<meta name="twitter:description" content="Order Coffee Online from Verve Coffee Roasters. Hand-roasted daily, enjoy craft coffees with unique tasting &amp; roasting profiles. Free Shipping on orders $35+.">\n\n\n    <script src="//cdn.shopify.com/s/files/1/0035/9372/t/429/assets/zg-custom.global.js?v=5860858460324619171682115331" defer="defer"></script>\n    <script src="//cdn.shopify.com/s/files/1/0035/9372/t/429/assets/zg-custom.product-card.js?v=79935234076553762971682114716" defer="defer"></script>\n    <script>window.performance && window.performance.mark && window.performance.mark(\'shopify.content_for_header.start\');</script><meta name="google-site-verification" content="PzM6AfnrBp2FhlD2jIJ-HuJF8QCbApnNb9c7aS-Pz0o">\n<meta id="shopify-digital-wallet" name="shopify-digital-wallet" content="/359372/digital_wallets/dialog">\n<meta name="shopify-checkout-api-token" content="ff9de7ec7136d1629fa9118a1c46f5e9">\n<meta id="in-context-paypal-metadata" data-shop-id="359372" data-venmo-supported="true" data-environment="production" data-locale="en_US" data-paypal-v4="true" data-currency="USD">\n<meta id="amazon-payments-metadata" data-amazon-payments= ...
